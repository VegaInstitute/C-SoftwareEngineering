# %%
pip install clickhouse-driver
# Out:
# Collecting clickhouse-driver
#   Downloading clickhouse_driver-0.2.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pytz in /home/igudav/miniforge3/lib/python3.10/site-packages (from clickhouse-driver) (2024.1)
# Collecting tzlocal (from clickhouse-driver)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Downloading clickhouse_driver-0.2.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.9/935.9 kB 1.2 MB/s eta 0:00:0000:0100:01m
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Installing collected packages: tzlocal, clickhouse-driver
# Successfully installed clickhouse-driver-0.2.9 tzlocal-5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Raw client

# %%
from clickhouse_driver import Client

# %%
client = Client(host="localhost")

# %%
client.execute("show tables")
# Out:
# [('trades',)]

# %%
client.execute("select * from trades limit 10")
# Out:
# [(5437128382,
#   Decimal('60622.7'),
#   Decimal('0.013'),
#   Decimal('788.0951'),
#   datetime.datetime(2024, 10, 3, 3, 0, 0, 13000),
#   False),
#  (5437128383,
#   Decimal('60622.7'),
#   Decimal('0.131'),
#   Decimal('7941.5737'),
#   datetime.datetime(2024, 10, 3, 3, 0, 0, 42000),
#   False),
#  (5437128384,
#   Decimal('60622.6'),
#   Decimal('3.762'),
#   Decimal('228062.2212'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 550000),
#   True),
#  (5437128385,
#   Decimal('60622.6'),
#   Decimal('0.005'),
#   Decimal('303.113'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 553000),
#   True),
#  (5437128386,
#   Decimal('60622.7'),
#   Decimal('0.025'),
#   Decimal('1515.5675'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 557000),
#   False),
#  (5437128387,
#   Decimal('60622.6'),
#   Decimal('0.618'),
#   Decimal('37464.7668'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 558000),
#   True),
#  (5437128388,
#   Decimal('60622.6'),
#   Decimal('0.005'),
#   Decimal('303.113'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 558000),
#   True),
#  (5437128389,
#   Decimal('60622.6'),
#   Decimal('0.002'),
#   Decimal('121.2452'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 558000),
#   True),
#  (5437128390,
#   Decimal('60622.6'),
#   Decimal('0.018'),
#   Decimal('1091.2068'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 558000),
#   True),
#  (5437128391,
#   Decimal('60622.6'),
#   Decimal('0.008'),
#   Decimal('484.9808'),
#   datetime.datetime(2024, 10, 3, 3, 0, 3, 558000),
#   True)]

# %% [markdown]
# # DB API 2.0

# %%
from clickhouse_driver import connect
import pandas as pd

# %%
conn = connect(host="localhost")

# %%
df = pd.read_sql("select * from trades limit 10", conn)
df
# Out:
# /tmp/ipykernel_1504694/3659943209.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from trades limit 10", conn)
#            id    price    qty    quote_qty                    time  \
# 0  5437128382  60622.7  0.013     788.0951 2024-10-03 03:00:00.013
# 1  5437128383  60622.7  0.131    7941.5737 2024-10-03 03:00:00.042
# 2  5437128384  60622.6  3.762  228062.2212 2024-10-03 03:00:03.550
# 3  5437128385  60622.6  0.005     303.1130 2024-10-03 03:00:03.553
# 4  5437128386  60622.7  0.025    1515.5675 2024-10-03 03:00:03.557
# 5  5437128387  60622.6  0.618   37464.7668 2024-10-03 03:00:03.558
# 6  5437128388  60622.6  0.005     303.1130 2024-10-03 03:00:03.558
# 7  5437128389  60622.6  0.002     121.2452 2024-10-03 03:00:03.558
# 8  5437128390  60622.6  0.018    1091.2068 2024-10-03 03:00:03.558
# 9  5437128391  60622.6  0.008     484.9808 2024-10-03 03:00:03.558
#
#    is_buyer_maker
# 0           False
# 1           False
# 2            True
# 3            True
# 4           False
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True
