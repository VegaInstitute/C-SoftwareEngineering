# %%
pip install clickhouse-driver
# Out:
# Requirement already satisfied: clickhouse-driver in /home/igudav/miniforge3/lib/python3.10/site-packages (0.2.9)
# Requirement already satisfied: pytz in /home/igudav/miniforge3/lib/python3.10/site-packages (from clickhouse-driver) (2024.1)
# Requirement already satisfied: tzlocal in /home/igudav/miniforge3/lib/python3.10/site-packages (from clickhouse-driver) (5.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Raw client

# %%
from clickhouse_driver import Client

# %%
client = Client(host="localhost")

# %%
client.execute("show tables")
# Out:
# [('trades',)]

# %%
res = client.execute("select * from trades limit 10")
res
# Out:
# [(5260866540,
#   Decimal('55102.9'),
#   Decimal('0.106'),
#   Decimal('5840.9074'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 6000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866541,
#   Decimal('55102.9'),
#   Decimal('0.002'),
#   Decimal('110.2058'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 9000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866542,
#   Decimal('55102.7'),
#   Decimal('0.024'),
#   Decimal('1322.4648'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 13000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866543,
#   Decimal('55102.7'),
#   Decimal('0.084'),
#   Decimal('4628.6268'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 19000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866544,
#   Decimal('55102.7'),
#   Decimal('0.053'),
#   Decimal('2920.4431'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 19000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866545,
#   Decimal('55102.6'),
#   Decimal('0.003'),
#   Decimal('165.3078'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 19000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866546,
#   Decimal('55102.6'),
#   Decimal('0.023'),
#   Decimal('1267.3598'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 20000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866547,
#   Decimal('55102.6'),
#   Decimal('0.108'),
#   Decimal('5951.0808'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 20000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866548,
#   Decimal('55102'),
#   Decimal('0.002'),
#   Decimal('110.204'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 20000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True),
#  (5260866549,
#   Decimal('55100.5'),
#   Decimal('0.108'),
#   Decimal('5950.854'),
#   datetime.datetime(2024, 8, 8, 3, 0, 0, 20000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>),
#   True)]

# %%
dt = res[0][4]
dt
# Out:
# datetime.datetime(2024, 8, 8, 3, 0, 0, 6000, tzinfo=<DstTzInfo 'Europe/Moscow' MSK+3:00:00 STD>)

# %%
dt.timestamp()
# Out:
# 1723075200.006

# %% [markdown]
# # DB API 2.0

# %%
from clickhouse_driver import connect
import pandas as pd

# %%
conn = connect(host="localhost")

# %%
df = pd.read_sql("select * from trades limit 10", conn)
df
# Out:
# /tmp/ipykernel_1527007/3659943209.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from trades limit 10", conn)
#            id    price    qty  quote_qty                             time  \
# 0  5260866540  55102.9  0.106  5840.9074 2024-08-08 00:00:00.006000+00:00
# 1  5260866541  55102.9  0.002   110.2058 2024-08-08 00:00:00.009000+00:00
# 2  5260866542  55102.7  0.024  1322.4648 2024-08-08 00:00:00.013000+00:00
# 3  5260866543  55102.7  0.084  4628.6268 2024-08-08 00:00:00.019000+00:00
# 4  5260866544  55102.7  0.053  2920.4431 2024-08-08 00:00:00.019000+00:00
# 5  5260866545  55102.6  0.003   165.3078 2024-08-08 00:00:00.019000+00:00
# 6  5260866546  55102.6  0.023  1267.3598 2024-08-08 00:00:00.020000+00:00
# 7  5260866547  55102.6  0.108  5951.0808 2024-08-08 00:00:00.020000+00:00
# 8  5260866548  55102.0  0.002   110.2040 2024-08-08 00:00:00.020000+00:00
# 9  5260866549  55100.5  0.108  5950.8540 2024-08-08 00:00:00.020000+00:00
#
#    is_buyer_maker
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True

# %%
df.time.astype(int)
# Out:
# 0    1723075200006000000
# 1    1723075200009000000
# 2    1723075200013000000
# 3    1723075200019000000
# 4    1723075200019000000
# 5    1723075200019000000
# 6    1723075200020000000
# 7    1723075200020000000
# 8    1723075200020000000
# 9    1723075200020000000
# Name: time, dtype: int64
